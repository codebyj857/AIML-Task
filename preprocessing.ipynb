# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Load dataset directly from OpenML
df = pd.read_csv(
    "https://www.openml.org/data/get_csv/1587932/phpgNaXZe"
)

df.head()
# Out:
#        V1       V2      V3      V4      V5       V6      V7       V8       V9  \
# 0  1.4895  0.81688  2.1168  1.7836  1.5346 -0.30543 -1.2477 -0.14537 -0.59356
# 1  1.4895  0.81688  2.1168  1.7895  1.5403 -0.31850 -1.2477 -0.14537 -0.59356
# 2  1.4895  0.81688  2.1168  1.7836  1.5346 -0.30543 -1.2477 -0.14537 -0.59356
# 3  1.4895  0.81688  2.1168  1.7836  1.5346 -0.30543 -1.2477 -0.14537 -0.59356
# 4  1.4895  0.81688  2.1168  1.7836  1.5346 -0.30543 -1.2477 -0.14537 -0.59356
#
#        V10  ...       V43     V44      V45     V46     V47      V48     V49  \
# 0 -0.23316  ...  0.026975  1.8323  0.97743  2.6676  1.6803 -0.48278  1.4630
# 1 -0.23316  ...  0.026975  1.8323  0.97743  2.6676  1.6974 -0.48278  1.4801
# 2 -0.23316  ...  0.026975  1.8323  0.97743  2.6676  1.6917 -0.48278  1.4744
# 3 -0.23316  ...  0.026975  1.8323  0.97743  2.6676  1.6575 -0.48278  1.4401
# 4 -0.23316  ...  0.026975  1.8323  0.97743  2.6676  1.6632 -0.48278  1.4458
#
#        V50     V51  Class
# ...

# %%
# Dataset shape
print("Shape:", df.shape)

# Dataset info
df.info()

# First & last few rows
df.head()
df.tail()
# Out:
# Shape: (6118, 52)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6118 entries, 0 to 6117
# Data columns (total 52 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   V1      6118 non-null   float64
#  1   V2      6118 non-null   float64
#  2   V3      6118 non-null   float64
#  3   V4      6118 non-null   float64
#  4   V5      6118 non-null   float64
#  5   V6      6118 non-null   float64
#  6   V7      6118 non-null   float64
#  7   V8      6118 non-null   float64
#  8   V9      6118 non-null   float64
#  9   V10     6118 non-null   float64
#  10  V11     6118 non-null   float64
#  11  V12     6118 non-null   float64
#  12  V13     6118 non-null   float64
#  13  V14     6118 non-null   float64
#  14  V15     6118 non-null   float64
#  15  V16     6118 non-null   float64
#  16  V17     6118 non-null   float64
#  17  V18     6118 non-null   float64
#  18  V19     6118 non-null   float64
#  19  V20     6118 non-null   float64
# ...

# %%
missing_values = df.isnull().sum()

missing_values[missing_values > 0]
print("Total missing values:", df.isnull().sum().sum())
# Out:
# Total missing values: 0

# %%
import matplotlib.pyplot as plt

missing = df.isnull().sum()

plt.figure(figsize=(10,4))
missing.plot(kind='bar')
plt.title("Missing Values Per Column")
plt.ylabel("Count")
plt.xlabel("Columns")
plt.show()

# %%
# -------------------------------
# Block 4: Separate Column Types
# -------------------------------
num_cols = df.select_dtypes(include=['int64', 'float64']).columns
cat_cols = df.select_dtypes(include=['object']).columns

print("Number of numerical columns:", len(num_cols))
print("Number of categorical columns:", len(cat_cols))


# -----------------------------------------
# Block 5: Handle Missing Values (Imputation)
# -----------------------------------------

# Numerical columns → Median Imputation
for col in num_cols:
    if df[col].isnull().sum() > 0:
        df[col].fillna(df[col].median(), inplace=True)

# Categorical columns → Mode Imputation
for col in cat_cols:
    if df[col].isnull().sum() > 0:
        df[col].fillna(df[col].mode()[0], inplace=True)


# --------------------------------------------------
# Block 6: Remove Columns with High Missing Values
# --------------------------------------------------
threshold = 0.5 * len(df)
df = df.dropna(thresh=threshold, axis=1)


# ---------------------------------
# Block 7: Dataset Validation Check
# ---------------------------------
print("Total missing values after cleaning:", df.isnull().sum().sum())
print("Final dataset shape:", df.shape)


# --------------------------------
# Block 8: Save Cleaned Dataset
# --------------------------------
df.to_csv("cleaned_dataset.csv", index=False)
print("Cleaned dataset saved successfully.")
# Out:
# Number of numerical columns: 52
# Number of categorical columns: 0
# Total missing values after cleaning: 0
# Final dataset shape: (6118, 52)
# Cleaned dataset saved successfully.
